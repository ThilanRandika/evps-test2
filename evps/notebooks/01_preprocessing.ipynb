# %% [markdown]
# # Phase 2 Preprocessing
# Run the CLI helpers to build processed datasets.

# %%
# !python src/ml/preprocess_eta.py --seq-len 10 --horizon 1
# !python src/ml/preprocess_conflict.py --q-thresh 15 --moving-frac 0.25
